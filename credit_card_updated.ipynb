# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')

# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Encode categorical columns
le = LabelEncoder()
data['category'] = le.fit_transform(data['category'])
data['gender'] = le.fit_transform(data['gender'])

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, age):
    # Handle unseen categories
    if category not in le.classes_:
        le.classes_ = list(le.classes_) + [category]

    category = le.transform([category])[0]
    input_data = [[category, amt, age]]
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
age = int(input("Enter Age: "))

result = predict_fraud(category, amt, age)
print("Prediction:", result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-92319fe219a1> in <cell line: 0>()
#      32 # Scale the data
#      33 scaler = StandardScaler()
# ---> 34 X_train = scaler.fit_transform(X_train)
#      35 X_test = scaler.transform(X_test)
#      36
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')
# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Handle non-numeric columns
data.drop(['merchant'], axis=1, inplace=True)

# Encode categorical columns
le = LabelEncoder()
data['category'] = le.fit_transform(data['category'])
data['gender'] = le.fit_transform(data['gender'])

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, age):
    # Handle unseen categories
    if category not in le.classes_:
        le.classes_ = list(le.classes_) + [category]

    category = le.transform([category])[0]
    input_data = [[category, amt, age]]
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
age = int(input("Enter Age: "))

result = predict_fraud(category, amt, age)
print("Prediction:", result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a94aae893e12> in <cell line: 0>()
#      34 # Scale the data
#      35 scaler = StandardScaler()
# ---> 36 X_train = scaler.fit_transform(X_train)
#      37 X_test = scaler.transform(X_test)
#      38
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')
# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Handle non-numeric columns
data.drop(['merchant'], axis=1, inplace=True)

# Encode categorical columns
le = LabelEncoder()
data['category'] = le.fit_transform(data['category'])
data['gender'] = le.fit_transform(data['gender'])
data['job'] = le.fit_transform(data['job'])

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, age, job):
    # Handle unseen categories
    if category not in le.classes_:
        le.classes_ = list(le.classes_) + [category]
    if job not in le.classes_:
        le.classes_ = list(le.classes_) + [job]

    category = le.transform([category])[0]
    job = le.transform([job])[0]
    input_data = [[category, amt, age, job]]
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
age = int(input("Enter Age: "))
job = input("Enter Job: ")

result = predict_fraud(category, amt, age, job)
print("Prediction:", result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e7bfcabadb9c> in <cell line: 0>()
#      40 # Train the model
#      41 model = RandomForestClassifier()
# ---> 42 model.fit(X_train, y_train)
#      43
#      44 # Make predictions
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     358             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     359
# --> 360         X, y = validate_data(
#     361             self,
#     362             X,
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')

# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Handle non-numeric columns
data.drop(['merchant'], axis=1, inplace=True)

# Handle missing values
data.dropna(inplace=True)

# Encode categorical columns
le = LabelEncoder()
data['category'] = le.fit_transform(data['category'])
data['gender'] = le.fit_transform(data['gender'])
data['job'] = le.fit_transform(data['job'])

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, age, job):
    # Handle unseen categories
    if category not in le.classes_:
        le.classes_ = list(le.classes_) + [category]
    if job not in le.classes_:
        le.classes_ = list(le.classes_) + [job]

    category = le.transform([category])[0]
    job = le.transform([job])[0]
    input_data = [[category, amt, age, job]]
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
age = int(input("Enter Age: "))
job = input("Enter Job: ")

result = predict_fraud(category, amt, age, job)
print("Prediction:", result)
# Out:
# Accuracy: 0.9975887050626396
# Confusion Matrix:
#  [[553202    371]
#  [   969   1176]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    553573
#          1.0       0.76      0.55      0.64      2145
#
#     accuracy                           1.00    555718
#    macro avg       0.88      0.77      0.82    555718
# weighted avg       1.00      1.00      1.00    555718
#
# Enter Category: personal care
# Enter Transaction Amount: 8.36
# Enter Age: 16
# Enter Job: Machanical Engineer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-718ffc24a147> in <cell line: 0>()
#      82 job = input("Enter Job: ")
#      83
# ---> 84 result = predict_fraud(category, amt, age, job)
#      85 print("Prediction:", result)
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')

# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Handle non-numeric columns
data.drop(['merchant'], axis=1, inplace=True)

# Encode categorical columns
le_category = LabelEncoder()
le_gender = LabelEncoder()
le_job = LabelEncoder()
data['category'] = le_category.fit_transform(data['category'])
data['gender'] = le_gender.fit_transform(data['gender'])
data['job'] = le_job.fit_transform(data['job'])

# Drop rows with missing target values
data.dropna(subset=['is_fraud'], inplace=True)

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, job):
    # Handle unseen categories and jobs
    if category not in le_category.classes_:
        le_category.classes_ = np.append(le_category.classes_, category)
    if job not in le_job.classes_:
        le_job.classes_ = np.append(le_job.classes_, job)

    category = le_category.transform([category])[0]
    job = le_job.transform([job])[0]
    input_data = [[category, amt, job]]
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
job = input("Enter Job: ")

result = predict_fraud(category, amt, job)
print("Prediction:", result)
# Out:
# Accuracy: 0.9976300929608183
# Confusion Matrix:
#  [[553209    364]
#  [   953   1192]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    553573
#          1.0       0.77      0.56      0.64      2145
#
#     accuracy                           1.00    555718
#    macro avg       0.88      0.78      0.82    555718
# weighted avg       1.00      1.00      1.00    555718
#
# Enter Category: personal care
# Enter Transaction Amount: 2.86
# Enter Job: machanical enginner
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7b70aa30062a> in <cell line: 0>()
#      84 job = input("Enter Job: ")
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')


# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Handle non-numeric columns
data.drop(['merchant'], axis=1, inplace=True)

# Encode categorical columns
le_category = LabelEncoder()
le_gender = LabelEncoder()
le_job = LabelEncoder()
data['category'] = le_category.fit_transform(data['category'])
data['gender'] = le_gender.fit_transform(data['gender'])
data['job'] = le_job.fit_transform(data['job'])

# Drop rows with missing target values
data.dropna(subset=['is_fraud'], inplace=True)

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale only the relevant features for prediction
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[['category', 'amt', 'job']])
X_test_scaled = scaler.transform(X_test[['category', 'amt', 'job']])

# Train the model
model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, job):
    # Handle unseen categories and jobs
    if category not in le_category.classes_:
        le_category.classes_ = np.append(le_category.classes_, category)
    if job not in le_job.classes_:
        le_job.classes_ = np.append(le_job.classes_, job)

    category = le_category.transform([category])[0]
    job = le_job.transform([job])[0]
    input_data = [[category, amt, job]]
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
job = input("Enter Job: ")

result = predict_fraud(category, amt, job)
print("Prediction:", result)
# Out:
# Accuracy: 0.9973745676764114
# Confusion Matrix:
#  [[552990    583]
#  [   876   1269]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    553573
#          1.0       0.69      0.59      0.63      2145
#
#     accuracy                           1.00    555718
#    macro avg       0.84      0.80      0.82    555718
# weighted avg       1.00      1.00      1.00    555718
#
# Enter Category: personal care
# Enter Transaction Amount: 8.36
# Enter Job: machanical engineer
# Prediction: Not Spam (Legitimate Transaction)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Load the datasets
# Load the datasets
train_df = pd.read_csv('/content/fraudTrain.csv')
test_df = pd.read_csv('/content/fraudTest.csv')

# Combine train and test data for preprocessing consistency
data = pd.concat([train_df, test_df])

# Drop irrelevant columns
data.drop(['trans_date_trans_time', 'cc_num', 'first', 'last', 'street', 'city', 'state', 'zip', 'lat', 'long', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# Handle non-numeric columns
data.drop(['merchant'], axis=1, inplace=True)

# Encode categorical columns
le_category = LabelEncoder()
le_gender = LabelEncoder()
le_job = LabelEncoder()
data['category'] = le_category.fit_transform(data['category'])
data['gender'] = le_gender.fit_transform(data['gender'])
data['job'] = le_job.fit_transform(data['job'])

# Drop rows with missing target values
data.dropna(subset=['is_fraud'], inplace=True)

# Split data back into train and test
train_data = data.iloc[:len(train_df)]
test_data = data.iloc[len(train_df):]

# Separate features and target
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# Scale only the relevant features for prediction
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[['category', 'amt', 'job']])
X_test_scaled = scaler.transform(X_test[['category', 'amt', 'job']])

# Train the model
model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Function to predict if a transaction is fraud or not
def predict_fraud(category, amt, job):
    # Handle unseen categories and jobs
    if category not in le_category.classes_:
        le_category.classes_ = np.append(le_category.classes_, category)
    if job not in le_job.classes_:
        le_job.classes_ = np.append(le_job.classes_, job)

    category = le_category.transform([category])[0]
    job = le_job.transform([job])[0]

    # Create a DataFrame with column names to avoid warning
    input_data = pd.DataFrame([[category, amt, job]], columns=['category', 'amt', 'job'])
    input_data = scaler.transform(input_data)

    prediction = model.predict(input_data)
    if prediction[0] == 1:
        return "Spam (Fraudulent Transaction)"
    else:
        return "Not Spam (Legitimate Transaction)"

# Example usage
category = input("Enter Category: ")
amt = float(input("Enter Transaction Amount: "))
job = input("Enter Job: ")

result = predict_fraud(category, amt, job)
print("Prediction:", result)
# Out:
# Accuracy: 0.9973475755689036
# Confusion Matrix:
#  [[552987    586]
#  [   888   1257]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    553573
#          1.0       0.68      0.59      0.63      2145
#
#     accuracy                           1.00    555718
#    macro avg       0.84      0.79      0.81    555718
# weighted avg       1.00      1.00      1.00    555718
#
# Enter Category: shopping net
# Enter Transaction Amount: 24.45
# Enter Job: librarian
# Prediction: Not Spam (Legitimate Transaction)
